# %%
import nltk

from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run' ,'runner' , 'running', 'ran' , 'runs', 'easliy' , 'fairly']

# %%
for word in words:
  print(word , "--> " , p_stemmer.stem(word))
# Out:
# run -->  run
# runner -->  runner
# running -->  run
# ran -->  ran
# runs -->  run
# easliy -->  easliy
# fairly -->  fairli

# %% [markdown]
# snowBall stemmer

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')

# %%
words
# Out:
# ['run', 'runner', 'running', 'ran', 'runs', 'easliy', 'fairly']

# %%
for word in words:
  print(word, "--->" , s_stemmer.stem(word))
# Out:
# run ---> run
# runner ---> runner
# running ---> run
# ran ---> ran
# runs ---> run
# easliy ---> easliy
# fairly ---> fair

# %%
word ="consolingly"
print(f"porter stemmer :\n{word} ->" ,p_stemmer.stem(word))
print(f"\nsnowball stemmer :\n{word}" ,s_stemmer.stem(word))
# Out:
# porter stemmer :
# consolingly -> consolingli
#
# snowball stemmer :
# consolingly consol

# %%
phrase = "I am meeting him tomorrow at the meeting"

for word in phrase.split():
  print(f"porter stemmer :{word} ->" ,p_stemmer.stem(word))

  print(f"snowball stemmer :{word}" ,s_stemmer.stem(word) , "\n\n")
# Out:
# porter stemmer :I -> i
# snowball stemmer :I i
#
#
# porter stemmer :am -> am
# snowball stemmer :am am
#
#
# porter stemmer :meeting -> meet
# snowball stemmer :meeting meet
#
#
# porter stemmer :him -> him
# snowball stemmer :him him
#
#
# porter stemmer :tomorrow -> tomorrow
# snowball stemmer :tomorrow tomorrow
#
#
# porter stemmer :at -> at
# snowball stemmer :at at
#
#
# porter stemmer :the -> the
# snowball stemmer :the the
#
#
# porter stemmer :meeting -> meet
# snowball stemmer :meeting meet

# %% [markdown]
# #Lemmatization

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(u'I am a runner in a race because I love to run since I ran today')

for token in doc1:
  print(token.text , "\t" , token.pos_ , "\t" , token.lemma , "\t" , token.lemma_)
# Out:
# I 	 PRON 	 4690420944186131903 	 I
# am 	 AUX 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# I 	 PRON 	 4690420944186131903 	 I
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# I 	 PRON 	 4690420944186131903 	 I
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %%
def show_lemmas(text):
  for token in text:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

# %%
doc2 = nlp(u'I saw eighteen mice today!')
show_lemmas(doc2)
# Out:
# I            PRON   4690420944186131903    I
# saw          VERB   11925638236994514241   see
# eighteen     NUM    9609336664675087640    eighteen
# mice         NOUN   1384165645700560590    mouse
# today        NOUN   11042482332948150395   today
# !            PUNCT  17494803046312582752   !

# %%
doc3 = nlp(u"I am meeting him tommorrow at the meeting.")

show_lemmas(doc3)
# Out:
# I            PRON   4690420944186131903    I
# am           AUX    10382539506755952630   be
# meeting      VERB   6880656908171229526    meet
# him          PRON   1655312771067108281    he
# tommorrow    NOUN   15839087253969881949   tommorrow
# at           ADP    11667289587015813222   at
# the          DET    7425985699627899538    the
# meeting      NOUN   14798207169164081740   meeting
# .            PUNCT  12646065887601541794   .

# %%
doc4 = nlp(u"That's an enormous automobile")

show_lemmas(doc4)
# Out:
# That         PRON   4380130941430378203    that
# 's           AUX    10382539506755952630   be
# an           DET    15099054000809333061   an
# enormous     ADJ    17917224542039855524   enormous
# automobile   NOUN   7211811266693931283    automobile
