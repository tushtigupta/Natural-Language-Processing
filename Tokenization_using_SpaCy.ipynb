# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
my_string= '"We\'re ,moving to L.A.!"'
print(my_string)
# Out:
# "We're ,moving to L.A.!"

# %%
doc=nlp(my_string)

for token in doc:
  print(token.text,end='|')
# Out:
# "|We|'re|,|moving|to|L.A.|!|"|

# %%
doc2=nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
  print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3=nlp(u'A 5km NYC cab ride costs $10.30')
print(doc3)
# Out:
# A 5km NYC cab ride costs $10.30

# %%
for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4=nlp(u"Let's visit St. Louis in the U.S next year.")
for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S
# next
# year
# .

# %%
len(doc)
# Out:
# 9

# %% [markdown]
# Counting the vocab-entries

# %%
len(doc.vocab)
# Out:
# 794

# %% [markdown]
# Tokens can be retrieved by index position and slice

# %%
doc5=nlp(u"It is better to give than recieve")

# %%
doc5[2]
# Out:
# better

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[-4:]
# Out:
# to give than recieve

# %%
doc8=nlp(u'Apple o build a Hong Kong factory for $6 million')

for token in doc8:
  print(token.text,end:'|')
print('\n----')

for ent in doc8.ents:
  print(ent.text+'-',+ent.label_+'')
# Out:
#   File "/tmp/ipython-input-2210582952.py", line 4
#     print(token.text,end:'|')
#                         ^
# SyntaxError: invalid syntax
