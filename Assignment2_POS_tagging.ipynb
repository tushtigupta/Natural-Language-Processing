# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
The Amazon customer service team resolved my issue very quickly.
I received my order on time and the packaging was excellent.
However, the product quality did not match my expectations.
"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# Amazon           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# customer         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# service          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# team             POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# resolved         POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# issue            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# very             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# quickly          POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# received         POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# order            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# time             POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# packaging        POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# was              POS: AUX         TAG: VBD         DEP: conj  Description: verb, past tense
# excellent        POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# However          POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# product          POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# quality          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# did              POS: AUX         TAG: VBD         DEP: aux  Description: verb, past tense
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# match            POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# expectations     POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- The
# The          <--det       -- team
# Amazon       <--compound  -- team
# customer     <--compound  -- service
# service      <--compound  -- team
# team         <--nsubj     -- resolved
# resolved     <--ROOT      -- resolved
# my           <--poss      -- issue
# issue        <--dobj      -- resolved
# very         <--advmod    -- quickly
# quickly      <--advmod    -- resolved
# .            <--punct     -- resolved
#
#             <--dep       -- .
# I            <--nsubj     -- received
# received     <--ROOT      -- received
# my           <--poss      -- order
# order        <--dobj      -- received
# on           <--prep      -- received
# time         <--pobj      -- on
# and          <--cc        -- received
# the          <--det       -- packaging
# packaging    <--nsubj     -- was
# was          <--conj      -- received
# excellent    <--acomp     -- was
# .            <--punct     -- was
#
#             <--dep       -- .
# However      <--advmod    -- match
# ,            <--punct     -- match
# the          <--det       -- quality
# product      <--compound  -- quality
# quality      <--nsubj     -- match
# did          <--aux       -- match
# not          <--neg       -- match
# match        <--ROOT      -- match
# my           <--poss      -- expectations
# expectations <--dobj      -- match
# .            <--punct     -- match
#
#             <--dep       -- .

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# The Amazon customer service team resolved my issue very quickly.
#
#
#                SPACE      dep        --> The
#   The             DET        det        --> team
#   Amazon          PROPN      compound   --> team
#   customer        NOUN       compound   --> service
#   service         NOUN       compound   --> team
#   team            NOUN       nsubj      --> resolved
#   resolved        VERB       ROOT       --> resolved
#   my              PRON       poss       --> issue
#   issue           NOUN       dobj       --> resolved
#   very            ADV        advmod     --> quickly
#   quickly         ADV        advmod     --> resolved
#   .               PUNCT      punct      --> resolved
#
#                SPACE      dep        --> .
#
# Sentence: I received my order on time and the packaging was excellent.
#
#   I               PRON       nsubj      --> received
#   received        VERB       ROOT       --> received
#   my              PRON       poss       --> order
#   order           NOUN       dobj       --> received
#   on              ADP        prep       --> received
#   time            NOUN       pobj       --> on
#   and             CCONJ      cc         --> received
#   the             DET        det        --> packaging
#   packaging       NOUN       nsubj      --> was
#   was             AUX        conj       --> received
#   excellent       ADJ        acomp      --> was
#   .               PUNCT      punct      --> was
#
#                SPACE      dep        --> .
#
# Sentence: However, the product quality did not match my expectations.
#
#   However         ADV        advmod     --> match
#   ,               PUNCT      punct      --> match
#   the             DET        det        --> quality
#   product         NOUN       compound   --> quality
#   quality         NOUN       nsubj      --> match
#   did             AUX        aux        --> match
#   not             PART       neg        --> match
#   match           VERB       ROOT       --> match
#   my              PRON       poss       --> expectations
#   expectations    NOUN       dobj       --> match
#   .               PUNCT      punct      --> match
#
#                SPACE      dep        --> .

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c6cd272e535e4bd4be5774823e5493bb-0" class="displacy" width="6000" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Amazon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">team</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">resolved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">issue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">quickly.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">received</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">packaging</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">excellent.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">However,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">product</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">quality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">match</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor"
